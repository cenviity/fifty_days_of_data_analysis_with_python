# %% [markdown]
# # Day 3: Generating Random Arrays

# %%
import numpy as np

# %% [markdown]
# ## Q1

# %%
rng = np.random.default_rng(seed=7)
arr = rng.random((3, 4))
arr
# Out:
# array([[0.62509547, 0.8972138 , 0.77568569, 0.22520719],
#        [0.30016628, 0.87355345, 0.0052653 , 0.82122842],
#        [0.79706943, 0.46793495, 0.30303243, 0.27842561]])

# %% [markdown]
# ## Q2

# %%
rng = np.random.default_rng(seed=7)
arr = rng.integers(0, 10, (3, 4))
arr
# Out:
# array([[9, 6, 6, 8],
#        [5, 7, 8, 2],
#        [0, 3, 2, 8]])

# %% [markdown]
# ## Q3

# %%
rng = np.random.default_rng(seed=7)
arr = rng.standard_normal(1000)
arr
# Out:
# array([ 1.23015336e-03,  2.98745538e-01, -2.74137855e-01, -8.90591839e-01,
#        -4.54670785e-01, -9.91646555e-01,  6.01436026e-02,  1.34021525e+00,
#        -4.92206519e-01, -6.20474900e-01,  4.89842050e-01,  3.56887008e-01,
#         1.05414249e-01, -9.30468045e-01, -2.92518225e-02,  6.95303194e-01,
#        -1.34421455e+00, -4.57615761e-01, -1.90122274e+00, -1.28953774e+00,
#        -1.84173504e+00, -2.35091131e-01, -1.26744648e+00,  2.71264359e-01,
#         1.56751087e-01, -1.86930945e-01, -2.51675971e+00, -5.38692896e-01,
#        -4.85009454e-02,  1.13308986e-01, -1.53013577e+00, -4.77753276e-01,
#        -9.78519078e-01, -8.08837239e-01,  1.06089862e+00, -8.07534675e-01,
#        -3.25217049e-02,  8.84389867e-01, -5.83600433e-01, -1.11701950e-01,
#         1.10464143e-01,  6.37817743e-02, -1.22505583e+00,  7.61402304e-02,
#         1.35882342e+00, -1.54714468e+00,  8.59382688e-01,  1.19354026e-01,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 8))
plt.hist(arr, bins=20, color="orange")
plt.title("Standard normal distribution", fontsize=15)
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Q4

# %%
arr = ["Orange", "Apple", "Pear"]

# %%
arr_random_choice = np.random.choice(arr, size=(3, 4))
arr_random_choice
# Out:
# array([['Pear', 'Orange', 'Apple', 'Orange'],
#        ['Pear', 'Orange', 'Apple', 'Orange'],
#        ['Pear', 'Orange', 'Apple', 'Apple']], dtype='<U6')
